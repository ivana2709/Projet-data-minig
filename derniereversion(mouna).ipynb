# %%
b

# %%
! pip install webcolors
from sklearn import tree
import urllib.request
import json
import csv
import html
from bs4 import BeautifulSoup
from PIL import Image
import	PIL.Image
from scipy.spatial import KDTree
import numpy
import math
import matplotlib.pyplot as plot
from sklearn.cluster import KMeans
from scipy.spatial import KDTree
import webcolors
from statistics import mean
from webcolors import rgb_to_name
import numpy as np
import pandas as pd
import graphviz
import pydotplus
from webcolors import CSS3_HEX_TO_NAMES, hex_to_rgb
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier


  
with open("montagnes.html") as html_file:
  soup1 = BeautifulSoup(html_file, 'html.parser')
with open("villes.html") as html_file:
  soup2 = BeautifulSoup(html_file, 'html.parser')
with open("fruit.html") as html_file:
  soup3 = BeautifulSoup(html_file, 'html.parser')
with open("chat.html") as html_file:
  soup4 = BeautifulSoup(html_file, 'html.parser')
couleur='bghh'


def exif (i,Tab_link):
  img = PIL.Image.open("images1/image{}.jpg".format(i))
  exif_data = img._getexif()
  print(exif_data)
  return exif_data

#On donne à chaque image le tag qui lui convient
tab_image=[]
tag=[]
for i in range(100):
  tab_image.append( "images1/image"+str(i)+".jpg")
  if 0<=i<=29:
    tag.append('montagne')
  elif 30<=i<=59:
    tag.append('ville')
  elif 60<=i<=79:
    tag.append('fruit')
  elif 80<=i<=99:
    tag.append('chat')
  
print(tag)
image_tag=dict(zip(tab_image, tag))
print(image_tag)

def download (i,Tab_link,folder):
    filename ='image1{}.jpg'.format(i)
    full_path = '{}{}'.format(folder,filename)
    url = Tab_link
    response = urllib.request.urlretrieve(url,full_path)
    return 0 

Tab_link = []
folder='images1/'
for link in soup1.find_all("td"):
  Tab_link.append(link.text)
for link in soup2.find_all("td"):
  Tab_link.append(link.text)
for link in soup3.find_all("td"):
  Tab_link.append(link.text)
for link in soup4.find_all("td"):
  Tab_link.append(link.text)
#for i in range (len(Tab_link)):
 # download(i,Tab_link[i],folder)

def couleurDominante(img):
  nb_cluster = 1 # Nombre de cluster defini par l'utilisateur
  
  numarray = numpy.array(img.getdata(), numpy.uint8)
  clusters = KMeans(n_clusters = nb_cluster)
  clusters.fit(numarray)
  npbins = numpy.arange(0, nb_cluster+1)
  histogram = numpy.histogram(clusters.labels_, bins=npbins)
  labels = numpy.unique(clusters.labels_)
  histogram[0].sort() # On trie selon les valeurs des frq. des couleurs
  barlist = plot.bar(labels, histogram[0])
  size = []
  somme = histogram[0].sum()
  for j in range(nb_cluster):
      size.append((histogram[0][j]/somme) * 360) #On transforme les % en degrés

  for i in range(nb_cluster):
      barlist[i].set_color('#%02x%02x%02x' % (math.ceil(clusters.cluster_centers_[i][0]),   math.ceil(clusters.cluster_centers_[i][1]),math.ceil(clusters.cluster_centers_[i][2])))
  
  for i in range(nb_cluster):
      liste_couleur=('#%02x%02x%02x' % (math.ceil(clusters.cluster_centers_[i][0]),   math.ceil(clusters.cluster_centers_[i][1]),math.ceil(clusters.cluster_centers_[i][2])))

  
  print(liste_couleur)
  
 # conversion
  names = []
  rgb_values = []
  for color_hex, color_name in CSS3_HEX_TO_NAMES.items():
      names.append(color_name)
      rgb_values.append(hex_to_rgb(color_hex))

  kdt_db = KDTree(rgb_values)
  distance, index = kdt_db.query(hex_to_rgb(liste_couleur))
  print( f'{names[index]}')
  return(f'{names[index]}')
  
user1=[]
user2=[]
user3=[]
users=[user1,user2,user3]
table=[]
list_couleur=[]
result=[]
data1=[]
data=[]
data2=[]
imagesuser1=[]
imagesuser2=[]
imagesuser3=[]
imageusers=[imagesuser1,imagesuser2,imagesuser3]
imageArecommande=[]
tabBalise=[]

#on demande à l'utilisateur de choisir des images d'une maniére aléatoire
def choisirimage(user,imageuser):
    for i in range(6): #demander à l'utilisateur de choisir 4ne images
      n=input("choisissez des numéros de 0 à  99 pour sélectionner des images:") 
      imageuser.append("images1/image{}.jpg".format(n)) #liste des images que l'utilisateur a choisi
    print(imageuser)
    return (imageuser)


def choix(image):
  choix = input ( ' Vous aimez cette image?[oui ou non] ')
 #choix de l'utilisateur stocké dans la liste result
  if choix == "oui":
    result.append('Favorite')
  else:
    result.append('NotFavorite')
  return(result)

#on récupère les données à analyser
def donnees(img,data1):
  imagefichier = Image.open(img)
  couleur_dominante=couleurDominante(imagefichier)
  print(couleur_dominante)
  #afficher l'image pour l"utilisateur
  plot.imshow(imagefichier)
  plot.show()
  #demander à l'uilisateur de taguer une image
  for key,value in image_tag.items():
    if key==img:
      tags=value
  print(tags)
  donnee=np.array(imagefichier.getdata())
  list_couleur.append(donnee)
  
  #definir la taille d'une image
  size=imagefichier.size
  if size < (300,400):
    taille="thumbnail"
  elif (300,400) < size <(800,600):
    taille="medium"
  elif size >(800,600):
    taille="large"
  else:
    taille='NONE'
  if imagefichier.width<imagefichier.height:
    mode="portrait"
  else:
    mode="landscape"

  data1.append([taille,tags,couleur_dominante,mode])     
  print(data1) #liste des données de l'image
  return(data1)

def analyse(user,imageuser):
  image=choisirimage(user,imageuser) #appeler la fonction pour avoir la liste des images choisies par l'utilisateur
  
  for i in image:
    
    donnees(i,data1)
    result=choix(i)
  print(data1)

#On commence avec l'utilisateur 1
analyse(user1,imagesuser1)

#Nous allons construire un classificateur d'arbre de décision avec ces données

#creating dataframes
dataframe = pd.DataFrame(data1, columns=['size', 'tag','color','mode']) 
resultframe = pd.DataFrame(result, columns=['favorite'])
#generating numerical labels
le1 = LabelEncoder()
dataframe['size'] = le1.fit_transform(dataframe['size'])

le2 = LabelEncoder()
dataframe['tag'] = le2.fit_transform(dataframe['tag'])

le3 = LabelEncoder()
dataframe['color'] = le3.fit_transform(dataframe['color'])



le4 = LabelEncoder()
dataframe['mode'] = le4.fit_transform(dataframe['mode'])

le5 = LabelEncoder()
resultframe['favorite'] = le5.fit_transform(resultframe['favorite'])



#arbre de décision

#Use of random forest classifier
rfc = RandomForestClassifier(n_estimators=10, max_depth=2,
                  random_state=0)
rfc = rfc.fit(dataframe, resultframe.values.ravel())
#prediction
imageApredire=['images1/image0.jpg','images1/image5.jpg','images1/image90.jpg','images1/image20.jpg','images1/image98.jpg'] #liste des images à prédire (on a choisi que 3 images pour le test par contre on peut parcourir tout le dossier images)
for img in imageApredire:
  print(img)
  image=img
  data2=donnees(img,data2)
for i in range(len(imageApredire)):
  prediction = rfc.predict([
          [le1.transform([data2[i][0]])[0], le2.transform([data2[i][1]])[0],
          le3.transform([data2[i][2]])[0],le4.transform([data2[i][3]])[0]]])
  print(le5.inverse_transform(prediction))
  print(rfc.feature_importances_)
  if le5.inverse_transform(prediction)=='Favorite':
    imageArecommande.append(image)
  print("la liste des images à recommmander a l'utilisateur 1:",imageArecommande)
# Out:
# Requirement already satisfied: webcolors in /usr/local/lib/python3.7/dist-packages (1.11.1)
# ['montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'montagne', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'ville', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat', 'chat']
# {'images1/image0.jpg': 'montagne', 'images1/image1.jpg': 'montagne', 'images1/image2.jpg': 'montagne', 'images1/image3.jpg': 'montagne', 'images1/image4.jpg': 'montagne', 'images1/image5.jpg': 'montagne', 'images1/image6.jpg': 'montagne', 'images1/image7.jpg': 'montagne', 'images1/image8.jpg': 'montagne', 'images1/image9.jpg': 'montagne', 'images1/image10.jpg': 'montagne', 'images1/image11.jpg': 'montagne', 'images1/image12.jpg': 'montagne', 'images1/image13.jpg': 'montagne', 'images1/image14.jpg': 'montagne', 'images1/image15.jpg': 'montagne', 'images1/image16.jpg': 'montagne', 'images1/image17.jpg': 'montagne', 'images1/image18.jpg': 'montagne', 'images1/image19.jpg': 'montagne', 'images1/image20.jpg': 'montagne', 'images1/image21.jpg': 'montagne', 'images1/image22.jpg': 'montagne', 'images1/image23.jpg': 'montagne', 'images1/image24.jpg': 'montagne', 'images1/image25.jpg': 'montagne', 'images1/image26.jpg': 'montagne', 'images1/image27.jpg': 'montagne', 'images1/image28.jpg': 'montagne', 'images1/image29.jpg': 'montagne', 'images1/image30.jpg': 'ville', 'images1/image31.jpg': 'ville', 'images1/image32.jpg': 'ville', 'images1/image33.jpg': 'ville', 'images1/image34.jpg': 'ville', 'images1/image35.jpg': 'ville', 'images1/image36.jpg': 'ville', 'images1/image37.jpg': 'ville', 'images1/image38.jpg': 'ville', 'images1/image39.jpg': 'ville', 'images1/image40.jpg': 'ville', 'images1/image41.jpg': 'ville', 'images1/image42.jpg': 'ville', 'images1/image43.jpg': 'ville', 'images1/image44.jpg': 'ville', 'images1/image45.jpg': 'ville', 'images1/image46.jpg': 'ville', 'images1/image47.jpg': 'ville', 'images1/image48.jpg': 'ville', 'images1/image49.jpg': 'ville', 'images1/image50.jpg': 'ville', 'images1/image51.jpg': 'ville', 'images1/image52.jpg': 'ville', 'images1/image53.jpg': 'ville', 'images1/image54.jpg': 'ville', 'images1/image55.jpg': 'ville', 'images1/image56.jpg': 'ville', 'images1/image57.jpg': 'ville', 'images1/image58.jpg': 'ville', 'images1/image59.jpg': 'ville', 'images1/image60.jpg': 'fruit', 'images1/image61.jpg': 'fruit', 'images1/image62.jpg': 'fruit', 'images1/image63.jpg': 'fruit', 'images1/image64.jpg': 'fruit', 'images1/image65.jpg': 'fruit', 'images1/image66.jpg': 'fruit', 'images1/image67.jpg': 'fruit', 'images1/image68.jpg': 'fruit', 'images1/image69.jpg': 'fruit', 'images1/image70.jpg': 'fruit', 'images1/image71.jpg': 'fruit', 'images1/image72.jpg': 'fruit', 'images1/image73.jpg': 'fruit', 'images1/image74.jpg': 'fruit', 'images1/image75.jpg': 'fruit', 'images1/image76.jpg': 'fruit', 'images1/image77.jpg': 'fruit', 'images1/image78.jpg': 'fruit', 'images1/image79.jpg': 'fruit', 'images1/image80.jpg': 'chat', 'images1/image81.jpg': 'chat', 'images1/image82.jpg': 'chat', 'images1/image83.jpg': 'chat', 'images1/image84.jpg': 'chat', 'images1/image85.jpg': 'chat', 'images1/image86.jpg': 'chat', 'images1/image87.jpg': 'chat', 'images1/image88.jpg': 'chat', 'images1/image89.jpg': 'chat', 'images1/image90.jpg': 'chat', 'images1/image91.jpg': 'chat', 'images1/image92.jpg': 'chat', 'images1/image93.jpg': 'chat', 'images1/image94.jpg': 'chat', 'images1/image95.jpg': 'chat', 'images1/image96.jpg': 'chat', 'images1/image97.jpg': 'chat', 'images1/image98.jpg': 'chat', 'images1/image99.jpg': 'chat'}
# choisissez des numéros de 0 à  99 pour sélectionner des images:54
# choisissez des numéros de 0 à  99 pour sélectionner des images:65
# choisissez des numéros de 0 à  99 pour sélectionner des images:99
# choisissez des numéros de 0 à  99 pour sélectionner des images:97
# choisissez des numéros de 0 à  99 pour sélectionner des images:1
# choisissez des numéros de 0 à  99 pour sélectionner des images:6
# ['images1/image54.jpg', 'images1/image65.jpg', 'images1/image99.jpg', 'images1/image97.jpg', 'images1/image1.jpg', 'images1/image6.jpg']
# #8c928b
# gray
# gray
# ville
# [['medium', 'ville', 'gray', 'landscape']]
#  Vous aimez cette image?[oui ou non] non
# #615b61
# dimgray
# dimgray
# fruit
# [['medium', 'ville', 'gray', 'landscape'], ['large', 'fruit', 'dimgray', 'landscape']]
#  Vous aimez cette image?[oui ou non] non
# #77645c
# dimgray
# dimgray
# chat
# [['medium', 'ville', 'gray', 'landscape'], ['large', 'fruit', 'dimgray', 'landscape'], ['medium', 'chat', 'dimgray', 'portrait']]
#  Vous aimez cette image?[oui ou non] oui
# #a0938e
# rosybrown
# rosybrown
# chat
# [['medium', 'ville', 'gray', 'landscape'], ['large', 'fruit', 'dimgray', 'landscape'], ['medium', 'chat', 'dimgray', 'portrait'], ['large', 'chat', 'rosybrown', 'portrait']]
#  Vous aimez cette image?[oui ou non] oui
# #818b8c
# gray
# gray
# montagne
# [['medium', 'ville', 'gray', 'landscape'], ['large', 'fruit', 'dimgray', 'landscape'], ['medium', 'chat', 'dimgray', 'portrait'], ['large', 'chat', 'rosybrown', 'portrait'], ['large', 'montagne', 'gray', 'landscape']]
#  Vous aimez cette image?[oui ou non] non
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c142d6c9049f> in <module>()
#     199
#     200 #On commence avec l'utilisateur 1
# --> 201 analyse(user1,imagesuser1)
#     202
#     203 #Nous allons construire un classificateur d'arbre de décision avec ces données
#
# <ipython-input-24-c142d6c9049f> in analyse(user, imageuser)
#     194   for i in image:
#     195
# --> 196     donnees(i,data1)
#     197     result=choix(i)
#     198   print(data1)
#
# <ipython-input-24-c142d6c9049f> in donnees(img, data1)
#     157 def donnees(img,data1):
#     158   imagefichier = Image.open(img)
# --> 159   couleur_dominante=couleurDominante(imagefichier)
#     160   print(couleur_dominante)
#     161   #afficher l'image pour l"utilisateur
#
# <ipython-input-24-c142d6c9049f> in couleurDominante(img)
#      87   numarray = numpy.array(img.getdata(), numpy.uint8)
#      88   clusters = KMeans(n_clusters = nb_cluster)
# ---> 89   clusters.fit(numarray)
#      90   npbins = numpy.arange(0, nb_cluster+1)
#      91   histogram = numpy.histogram(clusters.labels_, bins=npbins)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _kmeans_single_lloyd(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     422             _labels_inertia(X, sample_weight, x_squared_norms, centers,
#     423                             precompute_distances=precompute_distances,
# --> 424                             distances=distances)
#     425
#     426         # computation of the means is also called the M-step of EM
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _labels_inertia(X, sample_weight, x_squared_norms, centers, precompute_distances, distances)
#     560             return _labels_inertia_precompute_dense(X, sample_weight,
#     561                                                     x_squared_norms, centers,
# --> 562                                                     distances)
#     563         inertia = _k_means._assign_labels_array(
#     564             X, sample_weight, x_squared_norms, centers, labels,
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _labels_inertia_precompute_dense(X, sample_weight, x_squared_norms, centers, distances)
#     497     # TODO: Once PR #7383 is merged use check_inputs=False in metric_kwargs.
#     498     labels, mindist = pairwise_distances_argmin_min(
# --> 499         X=X, Y=centers, metric='euclidean', metric_kwargs={'squared': True})
#     500     # cython k-means code assumes int32 inputs
#     501     labels = labels.astype(np.int32, copy=False)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in pairwise_distances_argmin_min(X, Y, axis, metric, metric_kwargs)
#     573     sklearn.metrics.pairwise_distances_argmin
#     574     """
# --> 575     X, Y = check_pairwise_arrays(X, Y)
#     576
#     577     if metric_kwargs is None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     139         X = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#     140                         copy=copy, force_all_finite=force_all_finite,
# --> 141                         estimator=estimator)
#     142         Y = check_array(Y, accept_sparse=accept_sparse, dtype=dtype,
#     143                         copy=copy, force_all_finite=force_all_finite,
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      48     # safely to reduce dtype induced overflows.
#      49     is_float = X.dtype.kind in 'fc'
# ---> 50     if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
#      51         pass
#      52     elif is_float:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     704         result = op(x, *args, **kwargs, dtype=np.float64)
#     705     else:
# --> 706         result = op(x, *args, **kwargs)
#     707     return result
#     708
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2240
#    2241     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2242                           initial=initial, where=where)
#    2243
#    2244
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %% [markdown]
# # Nouvelle section

# %%
from google.colab import drive
drive.mount('/content/drive')
